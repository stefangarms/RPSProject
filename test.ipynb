# %%
import cv2 # open cv library
import cvzone
import time # 
import os # 
import HandTrackingModule as h_mod
import mediapipe as mp
import random
import numpy as np


cap = cv2.VideoCapture(1)
# set video frame width to 640px
cap.set(3, 1080)
# set video frame height to 640px
cap.set(4, 720)
# Out:
# True

# %%
while True:
    # background img
    imgBG = cv2.imread("Resources/BG2.png")
    
    success, img = cap.read()

    # resize img to fit in Background box (640x755) #(640x750)
    imgScaled = cv2.resize(img, (0,0), None, 1.0417, 1.0417)
    imgScaled = imgScaled[:,220:860]
    # flip image
    imgScaled = cv2.flip(imgScaled, 1)
    
    # insert Scaled image in Background
    # imgBG[234:654, 440:750] = imgScaled
    imgBG[603:1353,1366:2006] = imgScaled #(640x750)

     # cv2.imshow("Image", img)
    cv2.imshow("BG", imgBG)
    cv2.imshow("ImgScaled", imgScaled)
    height = np.size(imgScaled, 0)
    width = np.size(imgScaled, 1)
    print([width, height])
    height = np.size(imgBG, 0)
    width = np.size(imgBG, 1)
    print([width, height])

    # cv2.imshow("BG", imgScaled)
    key = cv2.waitKey(1)
    # Press S to start game
    if key == ord('s'):
        startGame = True
        initialTime = time.time()
        stateResult = False

    # Press Q to quit loop and destroy windows
    if key == ord('q'):
        cv2.destroyAllWindows()
        for i in range(2):
            cv2.waitKey(1)
        break
# Out:
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# [640, 750]
# [2245, 1587]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [87], line 28
#      25 print([width, height])
#      27 # cv2.imshow("BG", imgScaled)
# ---> 28 key = cv2.waitKey(1)
#      29 # Press S to start game
#      30 if key == ord('s'):
#
# KeyboardInterrupt:
